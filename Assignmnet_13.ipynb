# %% [markdown]
# 1.	What advantages do Excel spreadsheets have over CSV spreadsheets?

# %% [markdown]
# Ans: CSV files are faster and also consumes less data where as excel file consumes more memory space while importing.
# CSV fie can be opened with any text format where excel file can not be opend with any text format.
# Excel is more powerful tool than CSV. It can perform operation on the data but CSV can not.

# %% [markdown]
# 2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?

# %% [markdown]
# Ans:
# With open(“filename.csv” , “r”) as f:
# Reader = csv.reader(f)
# For data in f:
# 	Print(data)
# #this commands we suoppse to pass when we want to read the data.
# with open("test_csv_module1.1.csv" , "w") as file:
#     writer = csv.writer(file,)
#     writer.writerow(["okay" , "to" , "go"])
#     writer.writerow(["not" , "oaky" , "to go"])

# %% [markdown]
# 2.	What modes do File objects for reader and writer objects need to be opened in?

# %% [markdown]
# Ans: there is read mode “r” and write mode “w” for the file object.

# %% [markdown]
# 3.	What method takes a list argument and writes it to a CSV file?

# %% [markdown]
# Ans:
# Writer = csv.writer(file)
# Writer.writerow(list input)
# #This will write list argument into the csv format.

# %% [markdown]
# 4.	What do the keyword arguments delimiter and line terminator do?

# %% [markdown]
# Ans:
# Delimiter: Delimiter is nothing but separator if we give delimiter = “@” then it will separate the line where there is @.
# Line Terminator: line terminator terminates the line generated by writer object. /n /r acts as a line terminator.

# %% [markdown]
# 5.	What function takes a string of JSON data and returns a Python data structure?

# %% [markdown]
# Ans:
# Data = json.load(Dic_name/filename)
# Data = json.loads(string name)
# Print(data)

# %% [markdown]
# 6.	What function takes a Python data structure and returns a string of JSON data?

# %% [markdown]
# Ans:
# Json.dump(data , file_name)   # with this function we can load import pyhton data into json file format. Before that we suppose to create a json file by usin with open function
